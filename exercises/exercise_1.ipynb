# %% [markdown]
# ## 0. Pythagorean theorem (*)
#
# a) A right angled triangle has the catheti: a = 3 and b = 4 length units. Compute the hypothenuse of the triangle. (\*)
#
# hypotenuse formula:
# c = sqrt(a**2 + b**2)

# %%
import math
a = 3
b = 4
c = math.sqrt (a**2 + b**2)
print(c)
# Out:
# 5.0

# %% [markdown]
# b) A right angled triangle has hypothenuse c = 7.0 and a cathetus a = 5.0 length units. Compute the other cathetus and round to one decimal. (\*)

# %%
import math
a = 5.0
c = 7.0

b = math.sqrt (c**2 - a**2)
print(b)

#python round function 
d = round(b, 2)
print(d)
# Out:
# 4.898979485566356
# 4.9

# %% [markdown]
# ## 1. Classification accuracy (\*)
#
# A machine learning algorithm has been trained to predict whether or not it would rain the next day. Out of 365 predictions, it got 300 correct, compute the accuracy of this model.

# %%
predicted = 300
total_days = 365

accuracy = round(300 / 365, 2) 
print(accuracy)
# Out:
# 0.82

# %% [markdown]
# The model has 82.2% accuracy. That means it predicted the weather correctly most of the time (300 out of 365 days).
#
# But whether this is good or not depends on the context:
#
# 🌧️ If missing rain is costly (like farmers, flood warnings, or event planning), then 82% may not be good enough. Because that means it still got 65 days wrong.
#
# 🌤️ If mistakes aren’t so serious (like just deciding whether to bring an umbrella), then 82% might be acceptable.

# %% [markdown]
# ## 2. Classification accuracy (\*)
#
# A machine learning model has been trained to detect fire. Here is the result of its predictions:
#
# ![](attachment:image.png)

# %% [markdown]
# The formula gave us 98.7% accuracy. That sounds really good, but it’s misleading.
#
# Here’s why:
#
# There were 13 real fires.
#
# The model only caught 2 of them and missed 11 fires.
#
# Missing fires is very bad (dangerous), even if the overall number looks nice.
#
# So in plain words:
# 👉 The model looks “smart” because it says “no fire” correctly most of the time (985 times).
# 👉 But it’s actually bad at spotting fires, which is the most important part.
#
# That’s why this model is not good, even though accuracy looks high.

# %% [markdown]
# ## 3. File metadata - format print (*)

# %% [markdown]
# There is a file with the following metadata:
#
# - name: orders_data.csv
# - file size: 3.14mb
# - modified 2024
#
# Create variables for each of them and print out the following to the screen
#
# ```
# === File metadata ===
# Filename: sales_data.csv
# Size (MB): 24.7
# Last Modified Year: 2023
# ```

# %%
name = "sales_data.cv"
file_size = 3.14
modified_year = "2024"

print (f"""=== File metadata ===,
       Filename: {name},
       Size MB: {file_size},
       Last Modified Year: {modified_year}"""
       )
# Out:
# === File metadata ===,
#        Filename: sales_data.cv,
#        Size MB: 3.14,
#        Last Modified Year: 2024

# %% [markdown]
# ## 4. Unit converter - inch to cm (*)
#
# Screen sizes are defined using inches for example my computer has 15'' and it corresponds to the diagonal of the screen. Let the user type in a value in inches and output the result in centimeters.

# %%
inches = float(input("Measurement in inches: "))

# formula to convert inch to cm
cm = int(2.54 * inches)
cm = round (cm, 2)

print(f'The legnth in centimeters is {cm}')
# Out:
# The legnth in centimeters is 35

# %% [markdown]
# ## 5. Count characters in a text (*)
#
# Create a program to let a user input a text, count the number of characters and print it out to the screen. Space can also be counted as a character here.

# %%
text = "Create a program to let a user input a text, count the number of characters and print it out to the screen. Space can also be counted as a character here."

a = len(text)
print(a)
# Out:
# 154

# %% [markdown]
# ## 6. Data types (*)
#
# Create variables of type bool, int, float, str and list. Then use `type` function and check each variables type.

# %%
radius = 5
cool_subject = "math"
is_cool = True
numbers = [1, 2, 3, 4, 5]

print("radius:", type(radius))
print("cool_subject:", type(cool_subject))
print("is_cool:", type(is_cool))
print("numbers:", type(numbers))
# Out:
# radius: <class 'int'>
# cool_subject: <class 'str'>
# is_cool: <class 'bool'>
# numbers: <class 'list'>

# %% [markdown]
# ## 7. Theory
#
# a) What is the difference between input() and print() in Python?
# input()
# - is like a "reciever of data" or "container" for a variable that the user types.
# print()
# - displays the "output" or "result" from a code.
#
#
#
# b) What data type does the input() function return by default? How can you use it to get numeric input?
# - string is always default.
# - Convert the string data type variable into float or integer data type.
#
#
#
# c) Explain how formatted string literals (f-strings) improve readability in output statements. Give an example.
# - f-strings lets the output look more clean compared to using +.
# - It is easier to read and change the variable because I can see where the variable will exactly be printed in the output.
# - No need to convert types because f-strings can handle it.
# - Changing variables is simple because I just need to update the varibale and not the whole sentence.
#
#
#
# d) Can a variable change its data type during runtime in Python? Show an example.
# YES
# - Variables are flexible. It is decided automatically based on the VALUE of the variable.
# - The VALUE can change depedning on the data type(string, float, integer, Bolean).
# - Example:
# x = 5 # Variable x is int
# x = "hi"  #Variable x is string
# x = 3.14  # Variable x is float
#
#
#
# e) What does it mean that Python is "dynamically typed"? How is that different from statically typed languages?
# dynamic means
# - No variable type declaration
# - Variable is automatically decided when the program runs
#
# - Dynamic sample
# x = 5 # Variable x is int
# x = "hi"  #Variable x is string
# x = 3.14  # Variable x is float
#
# - Static sample
# Java
# int = x 10;   # x must be an int
# x = "ten"   #  Error: can't assign string to integer

# %% [markdown]
# ## Glossary
#
# Fill in this table either by copying this into your own markdown file or copy it into a spreadsheet if you feel that is easier to work with.
#
# | terminology       | explanation |
# | ----------------- | ----------- |
# | data type         | kind of value (string, float, integer, boolean, etc.)
# | variable          | container for value
# | assignment        | assigning a value to variable x=1
# | dynamically typed | type decided auto at run time
# | input             | data given to program
# | output            | data siplayed to the program
# | type casting      | converting between types
# | boolean           | TRUE FALSE data type
# | string            | text inside ""
# | f-string          | formatted string with variable inside
# | indentation       | spaces and tabs for code blocks
# | convention        | common coding style or practice
# |                   |             |
