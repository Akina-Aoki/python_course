# %% [markdown]
# # Level 1: 🧮“Temperature Converter” Class
#
# practice:
#
# - constructor logic
#
# - validation
#
# - method design
#
# - clean __str__ output
#
# ## Goal
#
# Create a class called Temperature that stores a temperature value and can convert between Celsius, Fahrenheit, and Kelvin.
#
# ## Inputs / Outputs
#
# ### Input:
#
# The temperature value (a number).
#
# The unit type ("C", "F", or "K").
#
# ### Output:
#
# Converted values through methods.
#
# A pretty string representation when printed.
#
# Example:

# %%
temp = Temperature(25, "C")
print(temp)
# Output: "Temperature: 25°C | 77.0°F | 298.15K"

# %% [markdown]
# ## Requirements
#
# ### Constructor:
#
# Accepts two arguments: value (float or int) and unit (string).
#
# Validate: unit must be "C", "F", or "K".
#
# Raise ValueError if invalid.

# %%
if unit not in ("C", "F", "K"):
    raise ValueError("Invalid temperature unit")

# %% [markdown]
# ## Methods:
#
# to_celsius()
#
# to_fahrenheit()
#
# to_kelvin()
#
# `__str__()` → Return a clean one-line summary like above.
#
# All conversions must be mathematically correct.
#
# ### 🧠 Hint 2 – Conversion formulas
#
# You can always convert from any unit to Celsius first — then build the others off that.
# Use the known relationships:
#
# From Celsius to Fahrenheit: F = (C * 9/5) + 32
#
# From Fahrenheit to Celsius: C = (F - 32) * 5/9
#
# From Celsius to Kelvin: K = C + 273.15
#
# From Kelvin to Celsius: C = K - 273.15
#
# That means you can write one method, say to_celsius(), that checks what your current unit is and converts it.
#
#
# ## Constraints
#
# Use only basic Python — no external libraries.
#
# Assume Kelvin cannot go below 0 (absolute zero).
#
# Round to 2 decimal places for readability.

# %% [markdown]
# ### Hint 3 – Other conversions
#
# Once you can convert to Celsius, you can reuse that logic for the others:

# %%
def to_fahrenheit(self):
    c = self.to_celsius()
    return (c * 9/5) + 32

# %%
class Temperature:
    def __init__(self, value: float, unit: str,  to_unit:str, from_unit:str):
        """ 
        Validation: 
        Unit must be in 'C', 'F' or 'K'
        Value must be a float or int
        """
        if not isinstance (value, float):
            raise ValueError("Must be a number")

        """Kelvin cannot be below 0"""
        if to_unit == "K" and value < 0:
            raise ValueError("Kelvin cannot be below 0")
        
        """Unit can only be these 3 units"""
        if not isinstance self.to_unit and self.from_unit == "C", "F", "K":
            raise ValueTypeError("Must be F, C or K")
        
        if unit not in ("C", "F", "K"):
            raise ValueError("Invalid temperature unit")
    

#---------------------------------
#       INSTANSINATION
#---------------------------------

        self._value = value
        self.unit = unit
        self._to_unit = to_unit
        self._from_unit = from_unit


#---------------------------------
#          SET GETTER & SETTER
#---------------------------------
    @property
    def value(self):
        """Read only"""
        return self._value
    
    @property
    def to_unit(self):
        return self._to_unit

    @property
    def from_unit(self):
        return self._from_unit
    
    @value.setter
    def value(self, value: int):
        print("value setter triggered")


#---------------------------------
#          METHODS
#---------------------------------
"""
From Celsius to Fahrenheit: F = (C * 9/5) + 32

From Fahrenheit to Celsius: C = (F - 32) * 5/9

From Celsius to Kelvin: K = C + 273.15

From Kelvin to Celsius: C = K - 273.15
"""

    def to_celsius(self):
    
    
    def to_farenheit(self):
        C = self.to_celsius()
        return (C * 9/5) + 32

    def to_kelvin(self):
        C = self.to_celsius()
        return (C + 273.15)
# Out:
#   Cell In[1], line 16
#     if not isinstance self.to_unit and self.from_unit == "C", "F", "K":
#                       ^
# SyntaxError: invalid syntax
